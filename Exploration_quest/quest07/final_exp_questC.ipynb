# %%
from tensorflow.keras.datasets import cifar10

cifar10_classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
(x_train_full, y_train_full), (x_test_full, y_test_full) = cifar10.load_data()

# %%
cifar10_classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
from matplotlib import pyplot as plt

# %%
def plot_image(image, label, title=None):
    plt.imshow(image)
    plt.title(f'True Label: {label}' if title is None else title)
    plt.axis('off')
    plt.show()


error_id = 2405

# 원본 데이터셋에서 이미지와 레이블 추출
image = x_test_full[error_id]
true_label = y_test_full[error_id][0]

# 이미지 시각화
plot_image(image, cifar10_classes[true_label])

# %%
correct_label = 6
image_index = 2405

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
image = x_test_full[2405]
true_label = y_test_full[2405][0]
plot_image(image, cifar10_classes[true_label])

# %%
correct_label = 0
image_index = 6877

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 7

image_index = 8058

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 0

image_index = 2532

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 7
image_index = 7657

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 9
image_index = 1969

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 5
image_index = 2804

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 9
image_index = 6792

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 5
image_index = 1227

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 5
image_index = 5191

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 5
image_index = 5690

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 8
image_index = 1718

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 4
image_index = 2592

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 2
image_index = 4794

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 3
image_index = 5960

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 2
image_index = 165

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 9
image_index = 9227

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 5
image_index = 5632

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 9
image_index = 9352

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 6
image_index = 7846

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 8
image_index = 6966

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
correct_label = 3
image_index = 5468

y_test_full[image_index] = correct_label

plot_image(x_test_full[image_index], cifar10_classes[correct_label], title=f'Corrected Label: {cifar10_classes[correct_label]}')

# %%
import tensorflow as tf

# %%
X_train = x_train_full.reshape(-1, 32, 32, 3)
X_test = x_test_full.reshape(-1, 32, 32, 3)
y_train = tf.keras.utils.to_categorical(y_train_full)
y_test = tf.keras.utils.to_categorical(y_test_full)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2)
print(X_train.shape, y_train.shape)
# Out:
# (40000, 32, 32, 3) (40000, 10)

# %%
pip install keras-tuner
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import keras
import keras_tuner as kt
from sklearn.model_selection import train_test_split
import os
class DeepTuner(kt.Tuner):
    def run_trial(self, trial, X, y, validation_data, **fit_kwargs):
        model = self.hypermodel.build(trial.hyperparameters)
        model.fit(X, y, batch_size=trial.hyperparameters.Choice(
            'batch_size', [16, 32]), **fit_kwargs)


        X_val, y_val = validation_data
        eval_scores = model.evaluate(X_val, y_val)
        return {'loss': eval_scores[0], 'accuracy': eval_scores[1]}

# %%
import tensorflow as tf

model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, 3, activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.AveragePooling2D(2),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.AveragePooling2D(2),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256, activation='softmax'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# c:\Users\wlstj\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 15, 15, 32)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ...

# %%
def build_model(hp):
    model = tf.keras.Sequential()
    model.add(tf.keras.Input(shape = X_train.shape[1:], name = 'inputs'))
    for i in range(hp.Int('num_layers', min_value=2, max_value=2)):
              model.add(tf.keras.layers.Conv2D(hp.Int(
                  'units_{i}'.format(i=i), min_value=32, max_value=64, step=32), (3,3),activation='relu'))
              model.add(tf.keras.layers.AveragePooling2D(2))
              model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Flatten())
    for i in range(hp.Int('n_connections', 1,1)):
        model.add(tf.keras.layers.Dense(hp.Choice(f'n_nodes',
                                  values=[32,64,128, 256]), activation = 'relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation='softmax', name = 'outputs'))
    model.compile(optimizer = 'adam',loss='categorical_crossentropy',
        metrics=['accuracy'])
    return model

# %%
my_keras_tuner = DeepTuner(
    oracle=kt.oracles.BayesianOptimizationOracle(
        objective=kt.Objective('accuracy', 'max'),
        max_trials=32,
        seed=42),
    hypermodel=build_model,
    overwrite=True,
    project_name='my_keras_tuner')

# 해당 모델 학습시간은 약 10분정도 걸립니다!
my_keras_tuner.search(
    X_train, y_train, validation_data=(X_val, y_val), epochs=3)
# Out:
# Trial 32 Complete [00h 00m 32s]
# accuracy: 0.6037999987602234
#
# Best accuracy So Far: 0.6614999771118164
# Total elapsed time: 00h 21m 43s

# %%
best_hps = my_keras_tuner.get_best_hyperparameters(num_trials=32)[0]
model = build_model(best_hps)

# %%
model.fit(X_train, y_train, batch_size=32, epochs = 10)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.3736 - loss: 2.0931
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5809 - loss: 1.1815
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6392 - loss: 1.0212
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.6850 - loss: 0.8974
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.7177 - loss: 0.8043
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7419 - loss: 0.7284
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7659 - loss: 0.6691
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7882 - loss: 0.5974
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8063 - loss: 0.5476
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8210 - loss: 0.5020

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7122 - loss: 0.9177
# [0.9291768670082092, 0.7078999876976013]

# %%
import os

# %%
save_path = 'C:/Users/wlstj/aiffel/mlops/best_model/model/1'
fname = os.path.join(save_path, 'model.keras')
model.save(fname)
