# %% [markdown]
# <a href="https://colab.research.google.com/github/JinseokCodeDiary/first-repository/blob/master/Python_quest/busan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

busan_station = ['가야대','장신대', '연지공원', '박물관', '수로왕릉', '봉황','부원', '김해시청', '인제대',
                 '김해대학', '지내', '불암', '대사', '평강', '대저', '등구', '덕두', '공항',
                 '서부산유통지구', '괘법르네시떼', '사상', '양산', '남양산', '부산대양산캠퍼스', '증산','호포',
                 '금곡', '동원', '율리', '화명', '수정', '덕천', '구명', '구남', '모라', '덕포', '사상', '감전',
                 '모덕', '주례', '냉정','개금', '동의대', '가야', '부암', '서면', '전포', '국제금융센터·부산은행',
                 '문현', '지게골', '못골', '대연', '경성대부경대', '남천', '금련산', '광안', '수영', '민락', '센텀시티',
                 '벡스코', '동백', '해운대', '중동', '장산', '노포', '범어사', '남산', '두실', '구서', '장전', '부산대',
                 '온천장', '명륜', '동래', '교대', '연산', '시청', '양정', '부전', '범내골', '범일', '좌천', '부산진',
                 '초량', '부산역', '중앙', '남포', '자갈치', '토성', '동대신', '서대신', '대티', '괴정', '사하',
                 '당리', '하단', '신평', '동매', '장림', '신장림', '낫개', '다대포항', '다대포해수욕장', '안평',
                 '고촌', '윗반송', '영산대', '석대', '반여농산물시장', '금사', '서동', '명장', '충렬사', '낙민',
                 '수안', '미남', '신해운대', '센텀', '재송', '부산원동', '안락', '동래(동해선)', '거제', '거제해맞이',
                 '부전', '범일', '부산진(동해선)', '체육공원', '강서구청', '구포', '숙등', '남산정', '만덕', '사직',
                 '종합운동장', '물만골', '배산', '망미'
                 ]
x = [128.864948056, 128.867180973, 128.869260693, 128.871881008, 128.872176631, 128.874392686, 128.883930010,
     128.890390910,128.901831668 ,128.915591736, 128.923777263, 128.927846285, 128.938435392, 128.950763320,
     128.960545898, 128.963563763, 128.954195500, 128.948587774, 128.954968205, 128.977643179, 128.985899789,
     129.026357306, 129.019374378, 129.013939817, 129.010457274, 129.017760776, 129.017042052, 129.013457105,
     129.012849437, 129.013748318, 129.008976278, 129.005254462, 128.999506166, 128.995761871, 128.988658040,
     128.983967354, 128.984673157, 128.990911517, 128.98573524, 129.002975202, 129.011915576, 129.019834462,
     129.032424472, 129.042697364, 129.050478472, 129.058994207, 129.065219588, 129.066675900, 129.067193186,
     129.074200085, 129.084555262, 129.092278467, 129.100374262, 129.107841815, 129.110917747, 129.113006079,
     129.114740559, 129.121708487, 129.13252949, 129.138662244, 129.148573511, 129.158720478, 129.167789210,
     129.177243972, 129.095053241, 129.092633911, 129.092387228, 129.091372723, 129.091274418, 129.088161058,
     129.089396062, 129.086399582, 129.079713604, 129.078490642, 129.079977037, 129.081513136, 129.076554480,
     129.071179739, 129.062859882, 129.059239350, 129.059350310, 129.054338720, 129.047755972, 129.042916372,
     129.039332261, 129.036376710, 129.034652071, 129.026501986, 129.019798354, 129.017731510, 129.012088051,
     129.000043935, 128.992541464, 128.983196307, 128.973702525, 128.966759715, 128.960595744, 128.973986168,
     128.977358881, 128.976662386, 128.979680634, 128.971312784, 128.965616308, 129.171771387, 129.160488287,
     129.153630480, 129.146136832, 129.136893469, 129.123931491, 129.115083869, 129.107397654, 129.101802922,
     129.097730245, 129.090672094, 129.083820532, 129.068706933, 129.177045779, 129.124363303, 129.120101751,
     129.114197797, 129.100555140, 129.091127225, 129.074433577, 129.069115598, 129.060161295, 129.057515685,
     129.049592920, 128.969409855, 128.981962767, 128.996422429, 129.013036175, 129.023872231, 129.036426270,
     129.065192917, 129.067945231, 129.085812152, 129.095550213, 129.108203461
     ]


y = [35.266832870, 35.259512353, 35.249603255, 35.240055237, 35.232845681, 35.227242040, 35.226476624,
     35.227083296, 35.228120626, 35.228994010, 35.227503372, 35.222162219, 35.217649394, 35.214035853,
     35.213066722, 35.196120784, 35.181988713, 35.171927297, 35.166358796, 35.163264554, 35.162309368,
     35.338602780, 35.325410872, 35.316659574, 35.308245238, 35.280051325, 35.266915486, 35.259869050,
     35.246776371, 35.234547492, 35.22286916, 35.210256746, 35.202768002, 35.197972362, 35.189768954,
     35.173929393, 35.162177950, 35.155651889, 35.18113392, 35.150416815, 35.151162307, 35.153134838,
     35.154161111, 35.155807538, 35.157462694, 35.157708744, 35.152854756, 35.145554890, 35.139180110,
     35.135607636, 35.134729166, 35.135142555, 35.137575773, 35.142117945, 35.150072081, 35.157729627,
     35.166230982, 35.167321526, 35.16938232, 35.168967330, 35.161002844, 35.163593025, 35.166615974,
     35.170104986, 35.283966763, 35.273125137, 35.265244417, 35.256980463, 35.247168706, 35.237994756,
     35.229619804, 35.220254511, 35.212574649, 35.205521616, 35.195569883, 35.186072353, 35.179714247,
     35.172930480, 35.162474865, 35.147270790, 35.14078953, 35.134323157, 35.127720909, 35.121043841,
     35.114543693, 35.103752289, 35.097896588, 35.097330220, 35.100722409, 35.110291290, 35.110916821,
     35.103185823, 35.099957009, 35.099848946, 35.103581633, 35.106262885, 35.095237595, 35.089764080,
     35.082096329, 35.074812569, 35.065436017, 35.057718471, 35.048226750, 35.237373195, 35.236016258,
     35.232326731, 35.225530151, 35.218124178, 35.217744104, 35.215745335, 35.212995762, 35.205320661,
     35.200011458, 35.200268748, 35.201738626, 35.206454090, 35.181605042, 35.179633326, 35.188075178,
     35.193663233, 35.196093721, 35.197252732, 35.189652618, 35.181448482, 35.164632338, 35.145317885,
     35.128800536, 35.212490246, 35.211221949, 35.206676714, 35.212069861, 35.213330998, 35.213021279,
     35.198628992, 35.191571010, 35.176580174, 35.173483274, 35.171533410
     ]

# %%
len(y)
# Out:
# 138

# %%
len(x)
# Out:
# 138

# %%
len(busan_station)
# Out:
# 138

# %%
X = pd.DataFrame(x)
Y = pd.DataFrame(y)
Z = pd.DataFrame(busan_station)
XY = pd.concat([X, Y], axis=1)
XYZ = pd.concat([Z, XY], axis=1)
XYZ.columns = ['station','x', 'y',]
XYZ
# Out:
#     station           x          y
# 0       가야대  128.864948  35.266833
# 1       장신대  128.867181  35.259512
# 2      연지공원  128.869261  35.249603
# 3       박물관  128.871881  35.240055
# 4      수로왕릉  128.872177  35.232846
# ..      ...         ...        ...
# 133      사직  129.065193  35.198629
# 134   종합운동장  129.067945  35.191571
# 135     물만골  129.085812  35.176580
# 136      배산  129.095550  35.173483
# 137      망미  129.108203  35.171533
#
# [138 rows x 3 columns]

# %%
pip install openpyxl

# %%
file_path = 'busanstation1.csv'
XYZ.to_csv(file_path, index=False)
