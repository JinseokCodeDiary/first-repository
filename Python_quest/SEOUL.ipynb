# %% [markdown]
# <a href="https://colab.research.google.com/github/JinseokCodeDiary/first-repository/blob/master/Python_quest/SEOUL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import numpy as np

# Try reading the file with 'latin-1' encoding
station = pd.read_csv('/content/station.csv', encoding='latin-1')

# %%
station.head()
# Out:
#                ¿ªÀÌ¸§          y           x
# 0            °¡¶ô½ÃÀå  37.492522  127.118234
# 1             Á¾·Î3°¡  37.571607  126.991806
# 2                ¿À±Ý  37.502162  127.128111
# 3              µ¿´ë¹®  37.571420  127.009745
# 4  µ¿´ë¹®¿ª»ç¹®È­°ø¿ø  37.565138  127.007896

# %%
station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ¿ªÀÌ¸§  589 non-null    object
#  1   y       589 non-null    float64
#  2   x       589 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 13.9+ KB

# %%
columns_to_extract = ['y', 'x']

station_ex = station[columns_to_extract]
station_ex
# Out:
#              y           x
# 0    37.492522  127.118234
# 1    37.571607  126.991806
# 2    37.502162  127.128111
# 3    37.571420  127.009745
# 4    37.565138  127.007896
# ..         ...         ...
# 584  37.269043  127.152716
# 585  37.260752  127.159443
# 586  37.242115  127.168075
# 587  37.239151  127.178406
# 588  37.237964  127.190294
#
# [589 rows x 2 columns]

# %%
station_name = [
'가락시장',
'종로3가',
'오금',
'동대문',
'동대문역사문화공원',
'충무로',
'서울',
'신도림',
'이촌',
'왕십리',
'시청',
'교대',
'신설동',
'강변',
'까치산',
'을지로3가',
'홍대입구',
'광운대',
'상봉',
'망우',
'영등포구청',
'신길',
'을지로4가',
'합정',
'공덕',
'삼각지',
'약수',
'신당',
'동묘앞',
'석계',
'도봉산',
'불광',
'연신내',
'금정',
'수원',
'원인재',
'회기',
'대곡',
'디지털미디어시티',
'회룡',
'판교',
'오이도',
'이매',
'선정릉',
'종합운동장',
'천호',
'창동',
'사당',
'노원',
'군자',
'건대입구',
'고속터미널',
'총신대입구(이수)',
'대림',
'가산디지털단지',
'온수',
'부평구청',
'잠실',
'복정',
'모란',
'부평',
'당산',
'여의도',
'동작',
'김포공항',
'강남',
'양재',
'정자',
'강남구청',
'선릉',
'효창공원앞',
'태릉입구',
'검암',
'주안',
'인천',
'인천시청',
'청량리',
'중랑',
'충정로',
'청구',
'성신여대입구',
'보문',
'계양',
'기흥',
'옥수',
'도곡',
'수서',
'용산',
'종각',
'종로5가',
'제기동',
'을지로입구',
'탑석',
'419민주묘지',
'가오리',
'화계',
'한티',
'구룡',
'홍제',
'김유정',
'남춘천',
'성균관대',
'경찰병원',
'구일',
'야탑',
'삼송',
'화정',
'영등포시장',
'상일동',
'공릉',
'상도',
'박촌',
'구성',
'인하대',
'숭의',
'센트럴파크',
'국제업무지구',
'강매',
'달월',
'원흥',
'완정',
'지평',
'석바위시장',
'상왕십리',
'한양대',
'뚝섬',
'성수',
'청계산입구',
'북한산우이',
'구의',
'잠실나루',
'잠실새내',
'삼성',
'역삼',
'서초',
'방배',
'낙성대',
'서울대입구',
'봉천',
'신림',
'신대방',
'구로디지털단지',
'문래',
'신촌',
'이대',
'아현',
'용답',
'신답',
'도림천',
'양천구청',
'신정네거리',
'용두',
'지축',
'구파발',
'녹번',
'무악재',
'독립문',
'경복궁',
'안국',
'동대입구',
'금호',
'압구정',
'신사',
'잠원',
'남부터미널',
'매봉',
'대치',
'학여울',
'대청',
'일원',
'당고개',
'상계',
'숭실대입구',
'장승배기',
'신대방삼거리',
'보라매',
'신풍',
'남구로',
'철산',
'광명사거리',
'천왕',
'까치울',
'부천종합운동장',
'춘의',
'신중동',
'부천시청',
'상동',
'삼산체육관',
'굴포천',
'암사',
'강동구청',
'몽촌토성',
'석촌',
'송파',
'문정',
'장지',
'산성',
'남한산성입구',
'단대오거리',
'신흥',
'수진',
'귤현',
'임학',
'계산',
'경인교대입구',
'작전',
'갈산',
'부평시장',
'동수',
'부평삼거리',
'간석오거리',
'예술회관',
'인천터미널',
'문학경기장',
'선학',
'신연수',
'동춘',
'동막',
'캠퍼스타운',
'테크노파크',
'지식정보단지',
'인천대입구',
'검단오류',
'왕길',
'검단사거리',
'마전',
'독정',
'검바위',
'아시아드경기장',
'서구청',
'가정',
'가정중앙시장',
'석남',
'서부여성회관',
'인천가좌',
'가재울',
'주안국가산단',
'시민공원',
'석천사거리',
'모래내시장',
'만수',
'남동구청',
'인천대공원',
'운연',
'개화',
'공항시장',
'신방화',
'마곡나루',
'양천향교',
'가양',
'증미',
'등촌',
'염창',
'신목동',
'선유도',
'국회의사당',
'샛강',
'노들',
'흑석',
'구반포',
'신반포',
'사평',
'신논현',
'언주',
'삼성중앙',
'봉은사',
'청라국제도시',
'운서',
'공항화물청사',
'인천국제공항',
'영종',
'양재시민의숲',
'김량장',
'운동장·송담대',
'고진',
'보평',
'둔전',
'전대·에버랜드',
'발곡',
'범골',
'경전철의정부',
'의정부시청',
'흥선',
'의정부중앙',
'동오',
'새말',
'경기도청북부청사',
'효자',
'곤제',
'어룡',
'송산',
'솔밭공원',
'삼양',
'삼양사거리',
'솔샘',
'북한산보국문',
'정릉',
'동천',
'수지구청',
'성복',
'상현',
'광교중앙',
'광교',
'강남대',
'지석',
'어정',
'동백',
'초당',
'삼가',
'시청·용인대',
'명지대'
]

# %%
station1= pd.DataFrame(station_name)
station1.head()
station1.columns = ['station']
station1
# Out:
#        station
# 0         가락시장
# 1         종로3가
# 2           오금
# 3          동대문
# 4    동대문역사문화공원
# ..         ...
# 584         동백
# 585         초당
# 586         삼가
# 587     시청·용인대
# 588        명지대
#
# [589 rows x 1 columns]

# %%
pd.concat([station1, station_ex], axis=1)
# Out:
#        station          y           x
# 0         가락시장  37.492522  127.118234
# 1         종로3가  37.571607  126.991806
# 2           오금  37.502162  127.128111
# 3          동대문  37.571420  127.009745
# 4    동대문역사문화공원  37.565138  127.007896
# ..         ...        ...         ...
# 584         동백  37.269043  127.152716
# 585         초당  37.260752  127.159443
# 586         삼가  37.242115  127.168075
# 587     시청·용인대  37.239151  127.178406
# 588        명지대  37.237964  127.190294
#
# [589 rows x 3 columns]

# %%
station_coo = pd.concat([station1, station_ex], axis=1)
station_coo
# Out:
#        station          y           x
# 0         가락시장  37.492522  127.118234
# 1         종로3가  37.571607  126.991806
# 2           오금  37.502162  127.128111
# 3          동대문  37.571420  127.009745
# 4    동대문역사문화공원  37.565138  127.007896
# ..         ...        ...         ...
# 584         동백  37.269043  127.152716
# 585         초당  37.260752  127.159443
# 586         삼가  37.242115  127.168075
# 587     시청·용인대  37.239151  127.178406
# 588        명지대  37.237964  127.190294
#
# [589 rows x 3 columns]

# %%
file_path = 'station_coo.csv'
station_coo.to_csv(file_path, index=False)
